# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataframe = pd.read_csv("../models/models.csv")
dataframe
# Out:
#            id  random_seed data_structure  data_num_snps  \
# 0    11062148           42           pool          60000
# 1    11062203           42           pool          60000
# 2    11062213           42           pool          60000
# 3    11062218           42           pool          60000
# 4    11062234           42           pool          80000
# ..        ...          ...            ...            ...
# 257  12060438   4006541358         beacon          20000
# 258  12060450   2255110125         beacon          30000
# 259  12060453   3125988174         beacon          10000
# 260  12060457   1419570805         beacon          10000
# 261  12060500    333568135         beacon          50000
#
#      loader_genome_batch_size  loader_snp_batch_size  model_conv_num_layers  \
# 0                          32                  60000                      2
# 1                          32                  60000                      2
# 2                          32                  60000                      2
# 3                          32                  60000                      2
# 4                          32                  80000                      2
# ..                        ...                    ...                    ...
# 257                        44                  20000                      2
# 258                        27                  30000                      2
# 259                        49                  10000                      4
# 260                        48                  10000                      3
# 261                        29                  50000                      2
#
#     model_conv_channel_size model_conv_kernel_size model_conv_stride  ...  \
# 0                 (3, 4, 8)               (20, 10)            (2, 1)  ...
# 1                 (3, 4, 8)                 (3, 3)            (2, 2)  ...
# 2                 (3, 4, 8)               (20, 10)            (2, 2)  ...
# 3                 (3, 4, 8)               (20, 20)            (2, 1)  ...
# 4                 (3, 4, 8)               (20, 10)            (2, 1)  ...
# ..                      ...                    ...               ...  ...
# 257             (3, 40, 43)               (23, 18)            (6, 2)  ...
# 258             (3, 16, 40)               (15, 15)            (6, 7)  ...
# 259     (3, 24, 55, 25, 64)       (21, 11, 16, 15)     (3, 9, 1, 15)  ...
# 260         (3, 59, 50, 16)             (18, 8, 8)         (5, 1, 8)  ...
# 261             (3, 57, 16)               (12, 25)           (12, 8)  ...
#
#     trainer_learning_rate trainer_best_eval_epoch trainer_best_eval_loss  \
# 0                   0.001                     167               0.686292
# 1                   0.001                      16               0.691632
# 2                   0.001                     184               0.683538
# 3                   0.001                      10               0.688748
# 4                   0.001                       5               0.685630
# ..                    ...                     ...                    ...
# 257                 0.001                     203               0.693131
# 258                 0.001                     221               0.692708
# 259                 0.001                       8               0.688602
# 260                 0.001                      72               0.692761
# 261                 0.001                       2               0.689415
#
#     trainer_best_eval_acc tester_loss tester_acc tester_precision  \
# 0                0.616667    0.686584   0.591667         0.648649
# 1                0.550000    0.696164   0.525000         0.666667
# 2                0.583333    0.702030   0.500000         0.500000
# 3                0.575000    0.691836   0.508333         0.520000
# 4                0.591667    0.689844   0.525000         0.551724
# ..                    ...         ...        ...              ...
# 257              0.500000    0.693098   0.500000         0.500000
# 258              0.525000    0.692980   0.500000         0.500000
# 259              0.666667    0.697285   0.500000         0.500000
# 260              0.500000    0.691985   0.500000         0.000000
# 261              0.500000    0.696985   0.500000         0.000000
#
#     tester_recall tester_f1_score tester_auroc
# 0        0.400000        0.494845     0.591667
# 1        0.100000        0.173913     0.525000
# 2        0.200000        0.285714     0.500000
# 3        0.216667        0.305882     0.508333
# 4        0.266667        0.359551     0.525000
# ..            ...             ...          ...
# 257      1.000000        0.666667     0.500000
# 258      1.000000        0.666667     0.500000
# 259      1.000000        0.666667     0.500000
# 260      0.000000        0.000000     0.500000
# 261      0.000000        0.000000     0.500000
#
# [262 rows x 54 columns]

# %%
dataframe = dataframe[dataframe["data_structure"] == "beacon"]
dataframe
# Out:
#            id  random_seed data_structure  data_num_snps  \
# 131  12051849    738302537         beacon          40000
# 132  12051923   3687210726         beacon          20000
# 133  12051926    952741481         beacon          20000
# 134  12051927   3209557230         beacon         100000
# 135  12051929   1028271353         beacon          80000
# ..        ...          ...            ...            ...
# 257  12060438   4006541358         beacon          20000
# 258  12060450   2255110125         beacon          30000
# 259  12060453   3125988174         beacon          10000
# 260  12060457   1419570805         beacon          10000
# 261  12060500    333568135         beacon          50000
#
#      loader_genome_batch_size  loader_snp_batch_size  model_conv_num_layers  \
# 131                        39                  40000                      2
# 132                        35                  20000                      1
# 133                        24                  20000                      1
# 134                        60                 100000                      2
# 135                        34                  80000                      4
# ..                        ...                    ...                    ...
# 257                        44                  20000                      2
# 258                        27                  30000                      2
# 259                        49                  10000                      4
# 260                        48                  10000                      3
# 261                        29                  50000                      2
#
#     model_conv_channel_size model_conv_kernel_size model_conv_stride  ...  \
# 131             (3, 40, 23)                (10, 7)            (1, 1)  ...
# 132                 (3, 21)                  (30,)              (9,)  ...
# 133                 (3, 19)                  (16,)             (16,)  ...
# 134             (3, 17, 20)               (24, 14)          (14, 14)  ...
# 135     (3, 60, 62, 37, 26)       (12, 17, 27, 18)    (6, 2, 10, 16)  ...
# ..                      ...                    ...               ...  ...
# 257             (3, 40, 43)               (23, 18)            (6, 2)  ...
# 258             (3, 16, 40)               (15, 15)            (6, 7)  ...
# 259     (3, 24, 55, 25, 64)       (21, 11, 16, 15)     (3, 9, 1, 15)  ...
# 260         (3, 59, 50, 16)             (18, 8, 8)         (5, 1, 8)  ...
# 261             (3, 57, 16)               (12, 25)           (12, 8)  ...
#
#     trainer_learning_rate trainer_best_eval_epoch trainer_best_eval_loss  \
# 131                 0.001                      95               0.638733
# 132                 0.001                       3               0.693109
# 133                 0.001                      36               0.693084
# 134                 0.001                      54               0.689359
# 135                 0.001                      99               0.693143
# ..                    ...                     ...                    ...
# 257                 0.001                     203               0.693131
# 258                 0.001                     221               0.692708
# 259                 0.001                       8               0.688602
# 260                 0.001                      72               0.692761
# 261                 0.001                       2               0.689415
#
#     trainer_best_eval_acc tester_loss tester_acc tester_precision  \
# 131              0.583333    0.701924   0.475000         0.454545
# 132              0.566667    0.693314   0.500000         0.000000
# 133              0.516667    0.693054   0.500000         0.500000
# 134              0.583333    0.704086   0.466667         0.470588
# 135              0.500000    0.693118   0.500000         0.500000
# ..                    ...         ...        ...              ...
# 257              0.500000    0.693098   0.500000         0.500000
# 258              0.525000    0.692980   0.500000         0.500000
# 259              0.666667    0.697285   0.500000         0.500000
# 260              0.500000    0.691985   0.500000         0.000000
# 261              0.500000    0.696985   0.500000         0.000000
#
#     tester_recall tester_f1_score tester_auroc
# 131      0.250000        0.322581     0.475000
# 132      0.000000        0.000000     0.500000
# 133      1.000000        0.666667     0.500000
# 134      0.533333        0.500000     0.466667
# 135      1.000000        0.666667     0.500000
# ..            ...             ...          ...
# 257      1.000000        0.666667     0.500000
# 258      1.000000        0.666667     0.500000
# 259      1.000000        0.666667     0.500000
# 260      0.000000        0.000000     0.500000
# 261      0.000000        0.000000     0.500000
#
# [131 rows x 54 columns]

# %%
plt.figure(figsize=(6, 6))
plt.hist(dataframe["tester_acc"], bins=20, color="dodgerblue", label="Testing Accuracies")
plt.xlabel("Accuracy")
plt.ylabel("Frequency")
plt.title("Performance Landscape of Beacon Models")
plt.legend()
plt.savefig("../plots/beacon_performance_landscape.png")
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(dataframe["data_num_snps"], dataframe["tester_acc"], color="dodgerblue")
plt.xlabel("Number of SNPs")
plt.ylabel("Accuracy")
plt.title("Performance Landscape of Beacon Models")
plt.savefig("../plots/beacon_performance_landscape_num_snps.png")
plt.show()

# %%
series_bidrectional = dataframe["model_lstm_bidirectional"].str.contains("True")
series_bidrectional
# Out:
# 131     True
# 132     True
# 133     True
# 134     True
# 135     True
#        ...
# 257    False
# 258    False
# 259    False
# 260     True
# 261     True
# Name: model_lstm_bidirectional, Length: 131, dtype: bool

# %%
categories = pd.Categorical(series_bidrectional.map({True: 'True', False: 'False'}))
categories
# Out:
# ['True', 'True', 'True', 'True', 'True', ..., 'False', 'False', 'False', 'True', 'True']
# Length: 131
# Categories (2, object): ['False', 'True']

# %%
plt.figure(figsize=(6, 6))
plt.scatter(categories, dataframe['tester_acc'], color='dodgerblue')
plt.ylabel('Tester Accuracy')
plt.xlabel('Bidirectional')
plt.title('Beacon Testing Accuracy vs LSTM Bidirectional')
plt.savefig("../plots/beacon_performance_landscape_bidirectional.png")
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(dataframe["model_conv_num_layers"], dataframe["tester_acc"], color="dodgerblue")
plt.xlabel("Number of Convolutional Layers")
plt.ylabel("Accuracy")
plt.title("Beacon Testing Accuracy vs Number of Convolutional Layers")
plt.savefig("../plots/beacon_performance_landscape_num_conv_layers.png")
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(dataframe["model_lstm_num_layers"], dataframe["tester_acc"], color="dodgerblue")
plt.xlabel("Number of LSTM Layers")
plt.ylabel("Accuracy")
plt.title("Beacon Testing Accuracy vs Number of LSTM Layers")
plt.savefig("../plots/beacon_performance_landscape_num_lstm_layers.png")
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(dataframe["model_linear_num_layers"], dataframe["tester_acc"], color="dodgerblue")
plt.xlabel("Number of Linear Layers")
plt.ylabel("Accuracy")
plt.title("Beacon Testing Accuracy vs Number of Linear Layers")
plt.savefig("../plots/beacon_performance_landscape_num_linear_layers.png")
plt.show()
